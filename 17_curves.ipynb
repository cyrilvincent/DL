# %%
a = 1
b = -1
l = [a * x + b for x in range(1000)]

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(range(1000),range(1000))
plt.show()

# %%
a = 1
b = -1
c = 1
l = [a * x**2 + b * x + c for x in range(-1000,1000)]

# %%
plt.plot(range(-1000,1000),l)
plt.show()

# %%
a = 1
b = -1
c = 1
d = -1
l = [a * x**3 + b * x**2 + c * x + d for x in range(-1000,1000)]

# %%
plt.plot(range(-1000,1000),l)
plt.show()

# %%
l = [1 / x for x in range(1,1000)]

# %%
plt.plot(range(1,1000),l)
plt.show()

# %%
a = 0.1
l = [a * math.exp(x) for x in range(10)]

# %%
plt.plot(range(10),l)
plt.show()

# %%
import math
a = 10
b = 100
l = [a * math.sin(x / b) for x in range(1000)]

# %%
plt.plot(range(1000),l)
plt.show()

# %%
import math
a = 1
b = 50
c = 500
l = [a * math.sin(x / b) * math.exp(-x/c) for x in range(1000)]

# %%
plt.plot(range(1000),l)
plt.show()
